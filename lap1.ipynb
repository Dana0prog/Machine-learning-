# %%
print("Hello, I am Dana!")
print("I am studying Machine Learning at university.")
print("I want to be a data scientist!")
name = "Dana"
age = 23
height = 1.64
is_student = True

print(name)
print(age)
print(height)
print(is_student)

print(type(name))
print(type(age))
print(type(height))
print(type(is_student))

a = 15
b = 4

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor division:", a // b)
print("Remainder:", a % b)
print("Power:", a ** b)

name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Hello", name)
print("Next year you will be", age + 1)
mark = float(input("Enter your mark: "))

if mark >= 60:
    print("Pass")
else:
    print("Fail")

    mark = float(input("Enter your mark: "))

if mark >= 90:
    print("A")
elif mark >= 80:
    print("B")
elif mark >= 70:
    print("C")
elif mark >= 60:
    print("D")
else:
    print("F")

    marks = [75, 82, 91, 68, 88]

print("Marks:", marks)
print("First mark:", marks[0])
print("Third mark:", marks[2])
print("Number of marks:", len(marks))
print("Total:", sum(marks))
print("Highest:", max(marks))
print("Lowest:", min(marks))
print("Average:", sum(marks) / len(marks))
temperature = [25.4, 26.1, 27.3, 28.0, 26.8]

print("Number of observations:", len(temperature))
print("Average temperature:", sum(temperature) / len(temperature))
print("Minimum temperature:", min(temperature))
print("Maximum temperature:", max(temperature))

study_hours = [1, 2, 3, 4, 5, 6, 7]
marks = [50, 55, 60, 65, 72, 80, 88]

for i in range(len(study_hours)):
    print("Study hours:", study_hours[i], "Marks:", marks[i])

    marks = [50, 55, 60, 65, 72, 80, 88]

for mark in marks:
    if mark >= 60:
        print(mark, "Pass")
    else:
        print(mark, "Fail")

        study_hours = [1, 2, 3, 4, 5, 6, 7]
marks = [50, 55, 60, 65, 72, 80, 88]

for i in range(len(study_hours)):
    if marks[i] >= 60:
        result = "Pass"
    else:
        result = "Fail"
    print("Study hours:", study_hours[i], "Mark:", marks[i], "Result:", result)

study_hours = [1, 2, 3, 4, 5, 6, 7]
marks = [50, 55, 60, 65, 72, 80, 88]

print("Number of students:", len(marks))

print("Average study hours:", sum(study_hours) / len(study_hours))


print("Average marks:", sum(marks) / len(marks))

print("Highest mark:", max(marks))
print("Lowest mark:", min(marks))

print("\n--- All Samples ---")
for i in range(len(study_hours)):
    print("Student", i+1, ": Study hours =", study_hours[i], "Mark =", marks[i])


print("\n--- Pass/Fail ---")
for i in range(len(marks)):
    if marks[i] >= 60:
        result = "Pass"
    else:
        result = "Fail"
    print("Mark:", marks[i], "-", result)


pass_count = 0
for mark in marks:
    if mark >= 60:
        pass_count = pass_count + 1
print("\nNumber of passes:", pass_count)
# Out:
# Hello, I am Dana!
# I am studying Machine Learning at university.
# I want to be a data scientist!
# Dana
# 23
# 1.64
# True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Floor division: 3
# Remainder: 3
# Power: 50625
# Enter your name: mona
# Enter your age: 23
# Hello mona
# Next year you will be 24
# Enter your mark: 79
# Pass
# C
# Marks: [75, 82, 91, 68, 88]
# First mark: 75
# Third mark: 91
# Number of marks: 5
# Total: 404
# Highest: 91
# Lowest: 68
# Average: 80.8
# Number of observations: 5
# Average temperature: 26.72
# Minimum temperature: 25.4
# Maximum temperature: 28.0
# Study hours: 1 Marks: 50
# Study hours: 2 Marks: 55
# Study hours: 3 Marks: 60
# Study hours: 4 Marks: 65
# Study hours: 5 Marks: 72
# Study hours: 6 Marks: 80
# Study hours: 7 Marks: 88
# 50 Fail
# 55 Fail
# 60 Pass
# 65 Pass
# 72 Pass
# 80 Pass
# 88 Pass
# Study hours: 1 Mark: 50 Result: Fail
# Study hours: 2 Mark: 55 Result: Fail
# Study hours: 3 Mark: 60 Result: Pass
# Study hours: 4 Mark: 65 Result: Pass
# Study hours: 5 Mark: 72 Result: Pass
# Study hours: 6 Mark: 80 Result: Pass
# Study hours: 7 Mark: 88 Result: Pass
# Number of students: 7
# Average study hours: 4.0
# Average marks: 67.14285714285714
# Highest mark: 88
# Lowest mark: 50
#
# --- All Samples ---
# Student 1 : Study hours = 1 Mark = 50
# Student 2 : Study hours = 2 Mark = 55
# Student 3 : Study hours = 3 Mark = 60
# Student 4 : Study hours = 4 Mark = 65
# Student 5 : Study hours = 5 Mark = 72
# Student 6 : Study hours = 6 Mark = 80
# Student 7 : Study hours = 7 Mark = 88
#
# --- Pass/Fail ---
# Mark: 50 - Fail
# Mark: 55 - Fail
# Mark: 60 - Pass
# Mark: 65 - Pass
# Mark: 72 - Pass
# Mark: 80 - Pass
# Mark: 88 - Pass
#
# Number of passes: 5
